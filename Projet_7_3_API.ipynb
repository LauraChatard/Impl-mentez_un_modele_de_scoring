# %% [markdown]
# # API
#
# This notebook is a continuation of the notebook on model testing. Here, we will deploy the API.

# %% [markdown]
# # Import

# %%
import pandas as pd

# Charger le fichier JSON
df = pd.read_json('json_data.json')

# Afficher les premières lignes du DataFrame pour vérification
display(df.head())
# Out:
#    Unnamed: 0  SK_ID_CURR  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0       17265      120135            1             0                1
# 1      304358      452624            0             0                0
# 2      273138      416615            1             0                0
# 3      240896      378934            1             0                0
# 4       55563      164384            1             0                1
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0             0          202500.0    675000.0      24376.5         675000.0
# 1             0          121500.0    339241.5      16627.5         238500.0
# 2             0          126000.0    127350.0      12726.0         112500.0
# 3             0          270000.0    272520.0      21658.5         225000.0
# 4             1           90000.0    755190.0      36459.0         675000.0
#
#    ...  CC_NAME_CONTRACT_STATUS_Signed_MAX  \
# 0  ...                                 NaN
# 1  ...                                 0.0
# 2  ...                                 NaN
# 3  ...                                 0.0
# 4  ...                                 0.0
#
#    CC_NAME_CONTRACT_STATUS_Signed_MEAN  CC_NAME_CONTRACT_STATUS_Signed_SUM  \
# 0                                  NaN                                 NaN
# 1                                  0.0                                 0.0
# 2                                  NaN                                 NaN
# 3                                  0.0                                 0.0
# 4                                  0.0                                 0.0
#
#    CC_NAME_CONTRACT_STATUS_Signed_VAR  CC_NAME_CONTRACT_STATUS_nan_MIN  \
# 0                                 NaN                              NaN
# 1                                 0.0                              0.0
# 2                                 NaN                              NaN
# 3                                 0.0                              0.0
# 4                                 0.0                              0.0
#
#    CC_NAME_CONTRACT_STATUS_nan_MAX  CC_NAME_CONTRACT_STATUS_nan_MEAN  \
# 0                              NaN                               NaN
# 1                              0.0                               0.0
# 2                              NaN                               NaN
# 3                              0.0                               0.0
# 4                              0.0                               0.0
#
#    CC_NAME_CONTRACT_STATUS_nan_SUM  CC_NAME_CONTRACT_STATUS_nan_VAR  CC_COUNT
# 0                              NaN                              NaN       NaN
# 1                              0.0                              0.0      94.0
# 2                              NaN                              NaN       NaN
# 3                              0.0                              0.0      16.0
# 4                              0.0                              0.0      17.0
#
# [5 rows x 797 columns]

# %%
# Out:
# 2024-09-16 10:31:05.037 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.066
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/laurachatard/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-09-16 10:31:05.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.067 Session state does not function when running a script without `streamlit run`
# 2024-09-16 10:31:05.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-16 10:31:05.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
